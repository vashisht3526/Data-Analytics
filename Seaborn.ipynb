# %%
import pandas as pd

# %%
movies=pd.read_csv(r'F:\Downloads\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies['Genre'][5:10]
# Out:
# 5    Action
# 6    Comedy
# 7    Horror
# 8    Comedy
# 9    Comedy
# Name: Genre, dtype: object

# %%
movies.columns=['Film','Genre', 'CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Year=movies.Year.astype('category')
movies.Genre=movies.Genre.astype('category')
movies.Film=movies.Film.astype('category')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, y='AudienceRating', x='CriticRating', kind='hex')

# %%
j = sns.jointplot(data = movies, y='AudienceRating', x='CriticRating', kind='reg')

# %%
sns.distplot(movies.AudienceRating)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Density'>

# %%
sns.distplot(movies.CriticRating)
# Out:
# <Axes: xlabel='CriticRating', ylabel='Density'>

# %%
sns.displot(movies.CriticRating)

# %%
sns.set_style('white')

# %%
sns.displot(movies.AudienceRating, bins=15)

# %%
sns.histplot(movies.AudienceRating, bins=20)
# Out:
# <Axes: xlabel='AudienceRating', ylabel='Count'>

# %%
sns.lmplot(movies, x='AudienceRating', y='CriticRating', hue='Genre')

# %%
sns.boxplot(data=movies, x='Genre', y='CriticRating', hue='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
sns.histplot(movies[movies.Genre=='Drama'].BudgetMillions, bins=20)
sns.histplot(movies[movies.Genre=='Thriller'].BudgetMillions, bins=20)
sns.histplot(movies[movies.Genre=='Action'].BudgetMillions, bins=20)
sns.histplot(movies[movies.Genre=='Horror'].BudgetMillions, bins=20)
# Out:
# <Axes: xlabel='BudgetMillions', ylabel='Count'>

# %%
plt.hist([movies[movies.Genre=='Drama'].BudgetMillions,\
            movies[movies.Genre=='Thriller'].BudgetMillions,\
            movies[movies.Genre=='Action'].BudgetMillions,\
            movies[movies.Genre=='Horror'].BudgetMillions]
            , bins=20, stacked=True)
plt.show()

# %%
sns.lmplot(movies, x='CriticRating', y='AudienceRating',\
           fit_reg=False, hue='Genre')

# %%
sns.lmplot(movies, y='AudienceRating', x='CriticRating',\
           fit_reg=False, hue='Genre', height = 4, aspect=1)

# %%
sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, shade=True,  color='red')
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
f, axes=plt.subplots(1,2,figsize=(12,4))
sns.kdeplot(x=movies.CriticRating,y= movies.AudienceRating, ax=axes[0])
sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRating, ax=axes[1])
# Out:
# <Axes: xlabel='CriticRating', ylabel='AudienceRating'>

# %%
sns.violinplot(movies, y='CriticRating', x='Genre', hue='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
sns.boxplot(movies, x='Genre', y='CriticRating', hue='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='CriticRating'>

# %%
sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating', hue='Genre')
# Out:
# <Axes: xlabel='Year', ylabel='CriticRating'>

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.scatter,'AudienceRating', 'CriticRating')

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.hist, 'BudgetMillions')

# %%
axes=plt.subplots(2,2, figsize=(15,10))
sns.kdeplot(movies, )
# Out:
# <Axes: ylabel='Density'>
