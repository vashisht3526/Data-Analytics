# %% [raw]
# Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
store=pd.read_csv(r'C:\Users\admin\Desktop\DS & AI\21st - Pandas\21st - Pandas\Sample - Superstore_Orders.csv')
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
id(store)
# Out:
# 2104620931776

# %%
id(store)
# Out:
# 2104620931776

# %%
len(store)
# Out:
# 10194

# %%
store[['City', 'Manufacturer']]
# Out:
#                 City  Manufacturer
# 0            Houston  Message Book
# 1         Naperville           GBC
# 2         Naperville         Avery
# 3         Naperville         SAFCO
# 4       Philadelphia         Avery
# ...              ...           ...
# 10189  New York City  Wilson Jones
# 10190      Fairfield           GBC
# 10191       Loveland         Other
# 10192  New York City         Other
# 10193  Charlottetown  Wilson Jones
#
# [10194 rows x 2 columns]

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
store.isnull()
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %%
store.isnull().sum()
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store.dtypes
# Out:
# Category           object
# City               object
# Country/Region     object
# Customer Name      object
# Manufacturer       object
# Order Date         object
# Order ID           object
# Postal Code        object
# Product Name       object
# Region             object
# Segment            object
# Ship Date          object
# Ship Mode          object
# State/Province     object
# Sub-Category       object
# Discount          float64
# Profit            float64
# Quantity            int64
# Sales             float64
# dtype: object

# %%
store_categorical = store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
       'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
       'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category']]
store_categorical
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store_numerical = store[['Discount', 'Profit', 'Quantity', 'Sales']]
store_numerical
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
store.tail(6)
# Out:
#               Category           City Country/Region      Customer Name  \
# 10188  Office Supplies      Fairfield  United States         Erica Bern
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10188      Cardinal  30-12-2023  US-2023-115427       94533
# 10189  Wilson Jones  30-12-2023  US-2023-143259       10009
# 10190           GBC  30-12-2023  US-2023-115427       94533
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
#
# ...

# %%
store.head(7)
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 5        Furniture     Henderson  United States  Maria Etezadi        Global
# 6  Office Supplies     Henderson  United States  Maria Etezadi        Rogers
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
# 5  06-01-2020  US-2020-167199       42420
# 6  06-01-2020  US-2020-167199       42420
#
# ...

# %%
store[0:10354:10045]
# Out:
#               Category           City Country/Region  Customer Name  \
# 0      Office Supplies        Houston  United States  Darren Powers
# 10045  Office Supplies  San Francisco  United States  Michael Moore
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 0      Message Book  03-01-2020  US-2020-103800       77015
# 10045         Other  19-12-2023  US-2023-128160       94110
#
#                                             Product Name   Region   Segment  \
# 0      Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central  Consumer
# 10045          Deluxe Heavy-Duty Vinyl Round Ring Binder     West  Consumer
#
#         Ship Date       Ship Mode State/Province Sub-Category  Discount  \
# 0      07-01-2020  Standard Class          Texas        Paper       0.2
# 10045  24-12-2023    Second Class     California      Binders       0.2
#
#         Profit  Quantity   Sales
# 0       5.5512         2  16.448
# 10045  11.4600         2  36.672

# %%
len(store['City'])
# Out:
# 10194

# %%
row = store[store['City']=='Houston']
row
# Out:
#               Category     City Country/Region     Customer Name  \
# 0      Office Supplies  Houston  United States     Darren Powers
# 111    Office Supplies  Houston  United States          Shui Tom
# 134          Furniture  Houston  United States  Giulietta Weimer
# 138    Office Supplies  Houston  United States  Giulietta Weimer
# 146    Office Supplies  Houston  United States        Sam Craven
# ...                ...      ...            ...               ...
# 9897   Office Supplies  Houston  United States       Ken Brennan
# 9908   Office Supplies  Houston  United States       Ken Brennan
# 10077  Office Supplies  Houston  United States      Alex Grayson
# 10080  Office Supplies  Houston  United States      Alex Grayson
# 10081  Office Supplies  Houston  United States      Alex Grayson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 0      Message Book  03-01-2020  US-2020-103800       77015
# 111           Other  14-02-2020  US-2020-107706       77095
# ...

# %%
row1 = store[store['Customer Name']=='Sam Craven']
row1
# Out:
#              Category          City Country/Region Customer Name Manufacturer  \
# 146   Office Supplies       Houston  United States    Sam Craven        Other
# 295   Office Supplies       Houston  United States    Sam Craven        Xerox
# 296   Office Supplies       Houston  United States    Sam Craven        Xerox
# 631         Furniture         Plano  United States    Sam Craven          Hon
# 634   Office Supplies         Plano  United States    Sam Craven       Storex
# 635   Office Supplies         Plano  United States    Sam Craven        Array
# 636   Office Supplies         Plano  United States    Sam Craven        Xerox
# 637   Office Supplies         Plano  United States    Sam Craven        SAFCO
# 638        Technology         Plano  United States    Sam Craven      Okidata
# 639        Technology         Plano  United States    Sam Craven          HTC
# 1525        Furniture       Midland  United States    Sam Craven          Hon
# ...

# %%
row2 = store[store['Order ID']=='US-2020-157847']
row2
# Out:
#             Category     City Country/Region Customer Name Manufacturer  \
# 295  Office Supplies  Houston  United States    Sam Craven        Xerox
# 296  Office Supplies  Houston  United States    Sam Craven        Xerox
#
#      Order Date        Order ID Postal Code Product Name   Region   Segment  \
# 295  02-04-2020  US-2020-157847       77095   Xerox 1947  Central  Consumer
# 296  02-04-2020  US-2020-157847       77095   Xerox 1898  Central  Consumer
#
#       Ship Date     Ship Mode State/Province Sub-Category  Discount  Profit  \
# 295  06-04-2020  Second Class          Texas        Paper       0.2  10.465
# 296  06-04-2020  Second Class          Texas        Paper       0.2   9.352
#
#      Quantity   Sales
# 295         7  33.488
# 296         5  26.720

# %%
clean=store.drop_duplicates(subset=['Order ID'])
clean
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# 5            Furniture      Henderson  United States      Maria Etezadi
# 7      Office Supplies         Athens  United States      Jack O'Briant
# ...                ...            ...            ...                ...
# 10186        Furniture  New York City  United States  Patrick O'Donnell
# 10187  Office Supplies       Columbus  United States        Chuck Clark
# 10188  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
len(clean)
# Out:
# 5111

# %%
store['Sales']
# Out:
# UsageError: Unknown variable '['Sales']'

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
plt.plot()
