# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(10, 100, 10) 
y = np.random.randint(10, 100, 10)
x, y
# Out:
# (array([18, 39, 96, 26, 45, 69, 43, 79, 47, 61]),
#  array([28, 61, 75, 54, 41, 92, 20, 57, 93, 29]))

# %%
plt.plot(x,y, color ="blue", marker = '*', ls = 'dashdot')

# %%
plt.bar(x, y, color = 'cyan', align='edge', width = 2, edgecolor='red')
# Out:
# <BarContainer object of 10 artists>
